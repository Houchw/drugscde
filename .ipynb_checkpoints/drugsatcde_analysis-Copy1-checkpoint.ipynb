# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

plt.rcParams["font.sans-serif"] = ["simhei"]

# %%
with open("drugsInfo_1.jl", "rb") as f:
    data = [json.loads(line.strip()) for line in f.readlines()]

df = pd.DataFrame(data)
df.rec_date = pd.to_datetime(df.rec_date)
df.head()
# Out:
#         app_no app_type                                 corp_name  \
# 0  JYHZ1700260    进口再注册  费森尤斯卡比（德国）公司 费森尤斯卡比（德国）公司 费森尤斯卡比华瑞制药有限公司
# 1  JYHZ1700256    进口再注册      卡德博士制药有限公司 卡德博士制药有限公司 博赏管理咨询（上海）有限公司
# 2  JYHZ1700224    进口再注册                         无 无 默沙东研发（中国）有限公司
# 3     CXL00432       新药
# 4  CYHB1707666     补充申请                 上海朝晖药业有限公司 上海复星医药产业发展有限公司
#
#        drug_name drug_type inv_type   rec_date
# 0  肠内营养乳剂(TP-HE)        化药          2017-12-23
# 1           雌三醇栓        化药          2017-12-23
# 2   注射用亚胺培南西司他丁钠        化药          2017-12-23
# 3       酒石酸西尼必利片        化药        2        NaT
# 4          美洛昔康片        化药          2017-12-21

# %%
cleaned = df[df.rec_date.notnull()]
cleaned = cleaned.drop_duplicates(['app_no'])
cleaned.head()
# Out:
#         app_no app_type                                 corp_name  \
# 0  JYHZ1700260    进口再注册  费森尤斯卡比（德国）公司 费森尤斯卡比（德国）公司 费森尤斯卡比华瑞制药有限公司
# 1  JYHZ1700256    进口再注册      卡德博士制药有限公司 卡德博士制药有限公司 博赏管理咨询（上海）有限公司
# 2  JYHZ1700224    进口再注册                         无 无 默沙东研发（中国）有限公司
# 4  CYHB1707666     补充申请                 上海朝晖药业有限公司 上海复星医药产业发展有限公司
# 5  CXSL1700122       新药           成都银河生物医药有限公司 北京马力喏生物科技有限公司 四川大学
#
#                     drug_name drug_type inv_type   rec_date
# 0               肠内营养乳剂(TP-HE)        化药          2017-12-23
# 1                        雌三醇栓        化药          2017-12-23
# 2                注射用亚胺培南西司他丁钠        化药          2017-12-23
# 4                       美洛昔康片        化药          2017-12-21
# 5  抗CD19分子嵌合抗原受体修饰的自体T淋巴细胞注射液   治疗用生物制品        1 2017-12-21

# %%
drug_type = df[df.drug_type.notnull()].drug_type.value_counts()
drug_type.head()
# Out:
# 化药         120925
# 中药          36228
# 治疗用生物制品      5410
# 预防用生物制品      1770
# 体外诊断试剂       1384
# Name: drug_type, dtype: int64

# %%
drug_type[:5].plot(kind='bar')
plt.show()

# %%
cleaned.rec_date.value_counts().resample('3M').sum().plot(figsize = (16, 12), kind= 'bar')
plt.xlabel(u'时间', fontsize = 15)
plt.ylabel(u'申请数量', fontsize = 15)
plt.title(u'历年申请数量变化情况', fontsize = 20)
#plt.xlim('20101231', '20171231')
#plt.legend()

plt.show()

# %%
c_drug = cleaned[cleaned.drug_type == u'化药']
z_drug = cleaned[cleaned.drug_type == u'中药']
s_drug = cleaned[cleaned.drug_type.str.contains(u'生物制品')]

c_drug.rec_date.value_counts().resample('M').sum().plot(figsize = (16, 12), label = u'化药')
z_drug.rec_date.value_counts().resample('M').sum().plot(figsize = (16, 12), label = u'中药')
s_drug.rec_date.value_counts().resample('M').sum().plot(figsize = (16, 12), label = u'生物药')
#time_cnt.resample('M').sum().plot(figsize = (16, 12), label = u'全部申请')

plt.xlim('201401', '201712')

plt.xlabel(u'日期', fontsize = 15)
plt.ylabel(u'申请数量', fontsize = 15)
plt.title(u'各类申请数量随时间变化情况', fontsize = 20)
plt.legend()
plt.savefig(u'各类申请数量随时间变化情况.jpg')
plt.show()

# %%
cleaned[cleaned.app_type == u'新药'].rec_date.value_counts().resample('M').sum().plot(figsize = (16, 12), label = u'新药')
cleaned[cleaned.app_type == u'仿制'].rec_date.value_counts().resample('M').sum().plot(figsize = (16, 12), label = u'仿制')
#cleaned[cleaned.app_type == u'复审'].rec_date.value_counts().resample('M').sum().plot(figsize = (16, 12), label = u'复审')
#time_cnt.resample('M').sum().plot(figsize = (16, 12), label = u'全部申请')
plt.xlim('200010', '201712')
plt.legend()
plt.show()

# %%
cleaned[(cleaned.inv_type == '1') | (cleaned.inv_type == '1.1')].corp_name.value_counts()[:20]
# Out:
#                                            251
# 江苏恒瑞医药股份有限公司 江苏恒瑞医药股份有限公司 上海恒瑞医药有限公司        60
# 广东东阳光药业有限公司                                 48
# 和记黄埔医药（上海）有限公司                              27
# 山东轩竹医药科技有限公司                                23
# 江苏豪森药业集团有限公司 江苏豪森药业集团有限公司 江苏豪森医药研究院有限公司     23
# 惠氏制药有限公司                                    19
# 中国医学科学院药物研究所                                17
# 卡南吉医药科技（上海）有限公司                             17
# 浙江海正药业股份有限公司 浙江海正药业股份有限公司                   17
# 江苏豪森药业股份有限公司 江苏豪森药业股份有限公司                   17
# 北京诺华制药有限公司                                  15
# 江苏恒瑞医药股份有限公司 江苏恒瑞医药股份有限公司                   14
# 辉瑞制药有限公司                                    14
# 南京圣和药业股份有限公司 南京圣和药业股份有限公司                   14
# 齐鲁制药有限公司 齐鲁制药有限公司                           14
# 罗氏研发（中国）有限公司                                13
# 江苏豪森药业集团有限公司 江苏豪森药业集团有限公司                   13
# 中国科学院上海药物研究所                                12
# 昆泰医药发展（上海）有限公司                              12
# Name: corp_name, dtype: int64

# %%
cleaned.to_excel('drugs_received.xlsx', index = False, encoding = 'utf-8')

# %%
df = cleaned[cleaned.rec_date > '2014']
df.head()
# Out:
#         app_no app_type                                 corp_name  \
# 0  JYHZ1700260    进口再注册  费森尤斯卡比（德国）公司 费森尤斯卡比（德国）公司 费森尤斯卡比华瑞制药有限公司
# 1  JYHZ1700256    进口再注册      卡德博士制药有限公司 卡德博士制药有限公司 博赏管理咨询（上海）有限公司
# 2  JYHZ1700224    进口再注册                         无 无 默沙东研发（中国）有限公司
# 4  CYHB1707666     补充申请                 上海朝晖药业有限公司 上海复星医药产业发展有限公司
# 5  CXSL1700122       新药           成都银河生物医药有限公司 北京马力喏生物科技有限公司 四川大学
#
#                     drug_name drug_type inv_type   rec_date
# 0               肠内营养乳剂(TP-HE)        化药          2017-12-23
# 1                        雌三醇栓        化药          2017-12-23
# 2                注射用亚胺培南西司他丁钠        化药          2017-12-23
# 4                       美洛昔康片        化药          2017-12-21
# 5  抗CD19分子嵌合抗原受体修饰的自体T淋巴细胞注射液   治疗用生物制品        1 2017-12-21

# %%
df.shape
# Out:
# (25212, 7)

# %%
df.drug_type.notnull().count()
# Out:
# 25212

# %%
df.drug_type.value
