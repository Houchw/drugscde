# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import requests
import pandas as pd
import numpy as np
import json
import re

# %%
with open("drugsInfo_1.jl", "rb") as f:
    data = [json.loads(line.strip()) for line in f.readlines()]

df = pd.DataFrame(data)
df.rec_date = pd.to_datetime(df.rec_date)
df = df.drop_duplicates()
df.head()
# Out:
#         app_no app_type                                 corp_name  \
# 0  JYHZ1700260    进口再注册  费森尤斯卡比（德国）公司 费森尤斯卡比（德国）公司 费森尤斯卡比华瑞制药有限公司
# 1  JYHZ1700256    进口再注册      卡德博士制药有限公司 卡德博士制药有限公司 博赏管理咨询（上海）有限公司
# 2  JYHZ1700224    进口再注册                         无 无 默沙东研发（中国）有限公司
# 3     CXL00432       新药
# 4  CYHB1707666     补充申请                 上海朝晖药业有限公司 上海复星医药产业发展有限公司
#
#        drug_name drug_type inv_type   rec_date
# 0  肠内营养乳剂(TP-HE)        化药          2017-12-23
# 1           雌三醇栓        化药          2017-12-23
# 2   注射用亚胺培南西司他丁钠        化药          2017-12-23
# 3       酒石酸西尼必利片        化药        2        NaT
# 4          美洛昔康片        化药          2017-12-21

# %%
df.rec_date = df.rec_date.fillna('1900-01-01')

# %%
def companyForm(s):
    pattern = re.compile(u'( +[a-zA-Z0-9]*[\u4e00-\u9fa5]+\S*[$\u4e00-\u9fa5])')
    company = re.split(pattern, s)
    #print(company)
    company = [i.strip() for i in company if i != ""]
    #print(set(company))
    company = "|".join(set(company))
    return company

# %%
companyForm("河南省新乡联谊制药厂 河南省新乡联谊制药厂")
# Out:
# '河南省新乡联谊制药厂'

# %%
df.corp_name = df.corp_name.map(companyForm)
df.corp_name = df.corp_name.replace("", u"我确定不知道是啥公司")

# %%
corp_name = df.corp_name.drop_duplicates().values

# %%
df.app_type = df.app_type.replace("", "None")
df.drug_name = df.drug_name.replace("", u"药物名称")
df.drug_type = df.drug_type.replace("", u"药物类型")
df.inv_type = df.inv_type.replace("", u'注册分类')

# %%
df.shape
# Out:
# (143026, 7)

# %%
session = requests.Session() 
resp = session.post('https://demo.doublechaintech.com/drug/secUserManager/login/user/pass/', data = {'user':'SU000001','pass':'123456'})
print(resp.text)
resp = session.get('https://demo.doublechaintech.com/drug/secUserManager/selectApp/UA000000/')
print(resp.text)
# Out:
# {"usernameParmeter":null,"passwordParmeter":null}
# {"usernameParmeter":null,"passwordParmeter":null}

# %%
resp = session.post('https://demo.doublechaintech.com/drug/dataPlatformManager/addDrug/platformId/name/description/tokensExpr/',
                    data = {'name':u"药物名称",'description':u"药物名称",'platformId':'DP000001','tokensExpr':'none'})

# %%
print(resp.text)
# Out:
# {"usernameParmeter":null,"passwordParmeter":null}

# %%
def add_app(drug):
    session = requests.Session() 
    resp = session.post('https://demo.doublechaintech.com/drug/secUserManager/login/user/pass/', data = {'user':'SU000001','pass':'123456'})
    #print(resp.text)
    resp = session.get('https://demo.doublechaintech.com/drug/secUserManager/selectApp/UA000000/')
    #print(resp.text)
    resp = session.post('https://demo.doublechaintech.com/drug/dataPlatformManager/addDrugApplicationWithNames/dataPlatformId/applicationNumber/companyName/applicationTypeName/registrationTypeName/drugName/drugTypeName/applicationDate/description/tokenExpr/', 
                        data = {'dataPlatformId':'DP000001',
                        'applicationNumber':drug.app_no.strip(),
                        'companyName':drug.corp_name.strip(),
                        'registrationTypeName':drug.inv_type.strip(),
                        'applicationTypeName':drug.app_type.strip(),
                        'drugName':drug.drug_name.strip(),
                        'drugTypeName':drug.drug_type.strip(),
                        'applicationDate':drug.rec_date,
                        'description':str(dict(drug)),
                        'tokensExpr':'none'})
    if resp.text.find("Exception") > 0:
        print("Exception")
        print(resp.text[:50])
        print("")
    #print(resp.text)
    session.get('https://demo.doublechaintech.com/drug/secUserManager/logout')
    return "OK"

# %%
for l in range(5, 10):
    tmp = df.iloc[l]
    try:
        add_app(tmp)
    except:
        print(l)
# Out:
# {"usernameParmeter":null,"passwordParmeter":null}
# 5OK
# {"usernameParmeter":null,"passwordParmeter":null}
# 6OK
# {"usernameParmeter":null,"passwordParmeter":null}
# 7OK
# {"usernameParmeter":null,"passwordParmeter":null}
# 8OK
# {"usernameParmeter":null,"passwordParmeter":null}
# 9OK

# %%
tmp = df.loc[l]
data = {'dataPlatformId': 'DP000001', 'applicationNumber': tmp.app_no, 'companyName':tmp.corp_name, 
         'applicationTypeName':tmp.app_type , 'registrationTypeName':tmp.inv_type , 'drugName':tmp.drug_name, 
         'drugTypeName':tmp.drug_type , 'applicationDate': tmp.rec_date, 'description':'to be expect', 
         'tokensExpr':'none'}
#print(data)
# Out:
# str

# %%
len(df)
# Out:
# 143026

# %%
df[df.corp_name == ""]
# Out:
#              app_no app_type corp_name        drug_name drug_type inv_type  \
# 3          CXL00432       新药                   酒石酸西尼必利片        化药        2
# 14         Y0403574       仿制                    注射用尼麦角林        化药        6
# 15         Y0403633       仿制             复方氨基酸注射液（18AA）        化药        6
# 16         Y0403624     补充申请                     葡萄糖注射液        化药
# 17         Y0403597     补充申请                  葡萄糖氯化钠注射液        化药
# 18         Y0403644       仿制                    头孢羟氨苄胶囊        化药        6
# 19         Y0403629     补充申请                 葡萄糖氯化钠钾注射液        化药
# 20         Y0403488       仿制              羟乙基淀粉40氯化钠注射液        化药        6
# 21         Y0403498     补充申请                     葡萄糖注射液        化药
# 37         Y0403467       仿制                    注射用阿昔洛韦        化药        6
# 38         Y0303270       仿制                     联苯苄唑乳膏        化药        6
# 39         Y0300886       仿制                     补肾益脑胶囊        中药       11
# 40         Y0304300       仿制                      阿奇霉素片        化药        6
# 41         Y0401828       仿制                   苯磺酸氨氯地平片        化药        6
# 42         X0306241       新药                     法罗培南钠片        化药      3.1
# 43         X0401533       新药                  硝酸咪康唑阴道凝胶        化药        5
# 44         X0403052     补充申请                       阿那曲唑        化药
# 55         X0300559       新药                 注射用甲磺酸帕珠沙星        化药      3.1
# 56      CZL20020205       新药                    小儿咳喘平颗粒        中药        3
# 68      CXL20020247       新药                     盐酸罗哌卡因        化药        4
# 100        CZS95156       新药                      双料喉风片        中药
# 101     BFZ20020015       仿制                        金胆片        中药
# 102     CXL20020112       新药                       甲钴胺片        化药        4
# 103     BFX20010292       仿制                     葛眼素注射液        化药
# 142        CZL00031       新药                        白山片        中药
# 143        CZS99042       新药                       脉络清片        中药
# 144        CZS97077       新药                     伤湿止痛搽剂        中药
# 145        CZL98167       新药                       康胃颗粒        中药
# 146     CXB20020792       新药                 注射用克林霉素磷酸酯        化药        4
# 147        CZL99080       新药                    乙肝康复灵胶囊        中药
# ...             ...      ...       ...              ...       ...      ...
# 117726     Z10_0037   药械组合产品                        感冒灸        药械
# 117727     Z10_0036   药械组合产品                       冠心病灸        药械
# 132343     J12_0116   药械组合产品                  生长因子增强骨基质        化药
# 132572     Z11_1615   药械组合产品            食管内放射NiTi支架及输送器        化药
# 138663     J11_2371   药械组合产品                     含银泡沫敷料        药械
# 138664     J11_2415   药械组合产品                轻柔含银自粘性泡沫敷料        药械
# 138665     J11_2414   药械组合产品                  含银自粘性泡沫敷料        药械
# 138666     J11_2353   药械组合产品                   轻柔含银泡沫敷料        药械
# 139038     Z13_1096   药械组合产品                   一次性宫颈扩张器        药械
# 151152    进 14-4190   药械组合产品                     含银泡沫敷料        药械
# 151153     进14-4661   药械组合产品                  含碘抗菌敷料-粉末        药械
# 151154     进14-4657   药械组合产品                   含碘抗菌敷料-片        药械
# 151155     进14-4655   药械组合产品                   含碘抗菌敷料-膏        药械
# 151156     进14-4193   药械组合产品                  含银自粘性泡沫敷料        药械
# 151157     进14-4190   药械组合产品                     含银泡沫敷料        药械
# 151158     进14-4192   药械组合产品                轻柔含银自粘性泡沫敷料        药械
# 151159    进 14-4661   药械组合产品                  含碘抗菌敷料-粉末        药械
# 151161    进 14-4657   药械组合产品                   含碘抗菌敷料-片        药械
# 151162    进 14-4655   药械组合产品                   含碘抗菌敷料-膏        药械
# 151163    进 14-4193   药械组合产品                  含银自粘性泡沫敷料        药械
# 151164    进 14-4192   药械组合产品                轻柔含银自粘性泡沫敷料        药械
# 159237    进 14-5635   药械组合产品                 水胶体抗菌性伤口敷料        药械
# 159238     进14-5635   药械组合产品                 水胶体抗菌性伤口敷料        药械
# 161431   JQZ1600276       进口                  天然胶乳橡胶避孕套      药械组合
# 163095   CQZ1600412   药械组合产品             外科生物补片（腹壁修复专用）      药械组合
# 166462  CXHS0590004       新药                     司他夫定胶囊        化药        4
# 166463  CXHS0590005       新药                      奈韦拉平片        化药        4
# 166466  CXHS0590003       新药                     司他夫定胶囊        化药        4
# 166467  CXHS0590002       新药                     去羟肌苷散剂        化药        4
# 166468  CXHS0590001       新药                     去羟肌苷散剂        化药        4
#
#                    rec_date
# 3                1900-01-01
# 14               1900-01-01
# 15               1900-01-01
# 16               1900-01-01
# 17               1900-01-01
# 18               1900-01-01
# 19               1900-01-01
# 20               1900-01-01
# 21               1900-01-01
# 37               1900-01-01
# 38               1900-01-01
# 39               1900-01-01
# 40               1900-01-01
# 41               1900-01-01
# 42               1900-01-01
# 43               1900-01-01
# 44               1900-01-01
# 55               1900-01-01
# 56               1900-01-01
# 68               1900-01-01
# 100              1900-01-01
# 101              1900-01-01
# 102              1900-01-01
# 103              1900-01-01
# 142              1900-01-01
# 143              1900-01-01
# 144              1900-01-01
# 145              1900-01-01
# 146              1900-01-01
# 147              1900-01-01
# ...                     ...
# 117726  2010-10-28 00:00:00
# 117727  2010-10-28 00:00:00
# 132343  2012-11-15 00:00:00
# 132572  2012-11-30 00:00:00
# 138663  2013-09-13 00:00:00
# 138664  2013-09-13 00:00:00
# 138665  2013-09-13 00:00:00
# 138666  2013-09-13 00:00:00
# 139038  2013-10-09 00:00:00
# 151152  2015-03-01 00:00:00
# 151153  2015-03-01 00:00:00
# 151154  2015-03-01 00:00:00
# 151155  2015-03-01 00:00:00
# 151156  2015-03-01 00:00:00
# 151157  2015-03-01 00:00:00
# 151158  2015-03-01 00:00:00
# 151159  2015-03-01 00:00:00
# 151161  2015-03-01 00:00:00
# 151162  2015-03-01 00:00:00
# 151163  2015-03-01 00:00:00
# 151164  2015-03-01 00:00:00
# 159237  2016-03-28 00:00:00
# 159238  2016-03-28 00:00:00
# 161431  2016-11-25 00:00:00
# 163095  2017-05-20 00:00:00
# 166462  2005-08-17 00:00:00
# 166463  2005-08-17 00:00:00
# 166466  2005-08-17 00:00:00
# 166467  2005-08-17 00:00:00
# 166468  2005-08-17 00:00:00
#
# [15855 rows x 7 columns]

# %%
n = 10
for d in drug_name.values[10:]:
    try:
        createDrug = session.post('http://103.229.212.96/drug/dataPlatformManager/addDrug/platformId/name/description/tokensExpr/',
            data = {'name':d.strip(),'description':"https://www.baidu.com/s?wd="+d.strip(),'platformId':'DP000001','tokensExpr':'none'})
        n = n+1
    except:
        print(n)
# Out:
# 2533
# 2541
# 5866
# 8265
# 8315
# 8614
# 9258
# 9415
# 9827
# 9842
# 10009
# 10673
# 10691
# 10835
# 10900
# 11045
# 11223
# 11350
# 11357
# 11514
# 11563
# 12098
# 12099
# 12236
# 12515
# 13699
# 14307
# 14567
# 14776
# 14828
# 15356
# 15471
# 15510
# 15709
# 16024
# 17199
# 18794
# 20057
# 20312
# 20596
# 21248
# 23787
# 26202
# 26659
# 27842
# 28093
# 28884

# %%
drug_name.values[5866]
# Out:
# '葡萄糖酸亚铁糖浆'

# %%
tmp = """2533
2541
5866
8265
8315
8614
9258
9415
9827
9842
10009
10673
10691
10835
10900
11045
11223
11350
11357
11514
11563
12098
12099
12236
12515
13699
14307
14567
14776
14828
15356
15471
15510
15709
16024
17199
18794
20057
20312
20596
21248
23787
26202
26659
27842
28093
28884"""
tmp = tmp.split('\n')
tmp = [int(x) for x in tmp]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-f5fd766785cb> in <module>()
#      48 tmp = tmp.split('\n')
#      49 tmp = [int(x) for x in tmp]
# ---> 50 tmp[1,2,5]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
for n in tmp:
    d = drug_name.values[n]
    try:
        createDrug = session.post('http://103.229.212.96/drug/dataPlatformManager/addDrug/platformId/name/description/tokensExpr/',
            data = {'name':d.strip(),'description':"https://www.baidu.com/s?wd="+d.strip(),'platformId':'DP000001','tokensExpr':'none'})
       
    except:
        print(n)

# %%
len(drug_name.values)
# Out:
# 29100

# %%
len(set(drug_name.values))
# Out:
# 29100

# %%
df.drug_type.drop_duplicates()
# Out:
# 0              化药
# 5         治疗用生物制品
# 27             中药
# 69        预防用生物制品
# 178        体外诊断试剂
# 225          药用辅料
# 113356         药械
# 117218       药械组合
# Name: drug_type, dtype: object

# %%
drug_type = df.drug_type.drop_duplicates().values
for d in drug_type:
    try:
        createDrug = session.post('http://103.229.212.96/drug/dataPlatformManager/addDrugType/platformId/name/description/tokensExpr/',
            data = {'name':d.strip(),'description':"https://www.baidu.com/s?wd="+d.strip(),'platformId':'DP000001','tokensExpr':'none'})
       
    except:
        print(n)

# %%
df.inv_type.drop_duplicates()
# Out:
# 0
# 3               2
# 5               1
# 14              6
# 28              3
# 29            5.2
# 39             11
# 42            3.1
# 43              5
# 47              4
# 62            2.2
# 69              9
# 131             8
# 163           3.2
# 180           5.1
# 189           2.4
# 199             7
# 255            15
# 273           1.1
# 981           4+5
# 5190          2+5
# 7772          3+5
# 11756          13
# 12091         3.3
# 12758         1.5
# 13001          14
# 13259         1.3
# 14004          原4
# 18337          10
# 24016         1.2
# 42278          12
# 62554         1.6
# 63279         3.4
# 65325          原7
# 70278          原9
# 74805          原2
# 91467       13+14
# 93685         原10
# 98596         6.1
# 99229         6.2
# 103277        6.3
# 160563        2.3
# 161446        2.1
# 162936    2.1;2.4
# 163153    2.2;2.4
# 164599    2.4;2.2
# Name: inv_type, dtype: object

# %%
inv_type = df.inv_type.drop_duplicates().values
inv_type.sort()
inv_type = np.delete(inv_type, [1])
inv_type
# Out:
# array(['', '1.1', '1.2', '1.3', '1.5', '1.6', '10', '11', '12', '13',
#        '13+14', '14', '15', '2', '2+5', '2.1', '2.1;2.4', '2.2',
#        '2.2;2.4', '2.3', '2.4', '2.4;2.2', '3', '3+5', '3.1', '3.2',
#        '3.3', '3.4', '4', '4+5', '5', '5.1', '5.2', '6', '6.1', '6.2',
#        '6.3', '7', '8', '9', '原10', '原2', '原4', '原7', '原9'], dtype=object)

# %%
n = 1
for d in inv_type:
    try:
        createRegistrationType = session.post('http://103.229.212.96/drug/dataPlatformManager/addRegistrationType/platformId/name/description/tokensExpr/',
            data = {'name':d,'description':"待修改",'platformId':'DP000001','tokensExpr':'none'})
        n = n+1
    except:
        print(n)
# Out:
# 11
